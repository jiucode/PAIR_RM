# %%
import pandas as pd
import requests
import re
pd.set_option('display.max_columns', None)

# %%
url="https://apidatos.ree.es/es/datos/generacion/estructura-generacion?start_date=2011-01-01T00:00&end_date=2011-12-31T23:59&time_trunc=month"
res=requests.get(url)

# %%
res.status_code
# Out:
# 200

# %%
res.content
# Out:
# b'{"data":{"type":"Generaci\\u00f3n por tecnolog\\u00eda","id":"gen1","attributes":{"title":"Generaci\\u00f3n por tecnolog\\u00eda","last-update":"2019-06-12T15:32:24.000+02:00","description":null},"meta":{"cache-control":{"cache":"MISS"}}},"included":[{"type":"Hidr\\u00e1ulica","id":"10288","groupId":"1","attributes":{"title":"Hidr\\u00e1ulica","description":null,"color":"#0090d1","icon":null,"type":"Renovable","magnitude":null,"composite":false,"last-update":"2019-06-12T15:32:24.000+02:00","values":[{"value":5119512.38,"percentage":0.19976265684687228,"datetime":"2011-01-01T00:00:00.000+01:00"},{"value":2998051.279,"percentage":0.13054077867742991,"datetime":"2011-02-01T00:00:00.000+01:00"},{"value":3910363.276,"percentage":0.15741784652381913,"datetime":"2011-03-01T00:00:00.000+01:00"},{"value":3537937.995,"percentage":0.16467786027045764,"datetime":"2011-04-01T00:00:00.000+02:00"},{"value":2797500.027,"percentage":0.12856432984303148,"datetime":"2011-05-01T00:00:00.000+02:00"},{"
# ...

# %%
res.json()
# Out:
# {'data': {'type': 'Generación por tecnología',
#   'id': 'gen1',
#   'attributes': {'title': 'Generación por tecnología',
#    'last-update': '2019-06-12T15:32:24.000+02:00',
#    'description': None},
#   'meta': {'cache-control': {'cache': 'MISS'}}},
#  'included': [{'type': 'Hidráulica',
#    'id': '10288',
#    'groupId': '1',
#    'attributes': {'title': 'Hidráulica',
#     'description': None,
#     'color': '#0090d1',
#     'icon': None,
#     'type': 'Renovable',
#     'magnitude': None,
#     'composite': False,
#     'last-update': '2019-06-12T15:32:24.000+02:00',
#     'values': [{'value': 5119512.38,
#       'percentage': 0.19976265684687228,
#       'datetime': '2011-01-01T00:00:00.000+01:00'},
#      {'value': 2998051.279,
#       'percentage': 0.13054077867742991,
#       'datetime': '2011-02-01T00:00:00.000+01:00'},
#      {'value': 3910363.276,
#       'percentage': 0.15741784652381913,
#       'datetime': '2011-03-01T00:00:00.000+01:00'},
# ...

# %%
type(res.json())
# Out:
# dict

# %%
res.json().keys()
# Out:
# dict_keys(['data', 'included'])

# %%
res.json()["included"]
# Out:
# [{'type': 'Hidráulica',
#   'id': '10288',
#   'groupId': '1',
#   'attributes': {'title': 'Hidráulica',
#    'description': None,
#    'color': '#0090d1',
#    'icon': None,
#    'type': 'Renovable',
#    'magnitude': None,
#    'composite': False,
#    'last-update': '2019-06-12T15:32:24.000+02:00',
#    'values': [{'value': 5119512.38,
#      'percentage': 0.19976265684687228,
#      'datetime': '2011-01-01T00:00:00.000+01:00'},
#     {'value': 2998051.279,
#      'percentage': 0.13054077867742991,
#      'datetime': '2011-02-01T00:00:00.000+01:00'},
#     {'value': 3910363.276,
#      'percentage': 0.15741784652381913,
#      'datetime': '2011-03-01T00:00:00.000+01:00'},
#     {'value': 3537937.995,
#      'percentage': 0.16467786027045764,
#      'datetime': '2011-04-01T00:00:00.000+02:00'},
#     {'value': 2797500.027,
#      'percentage': 0.12856432984303148,
#      'datetime': '2011-05-01T00:00:00.000+02:00'},
#     {'value': 2070305.344,
# ...

# %%
res.json()["included"]

type(res.json()["included"])
# Out:
# list

# %%
res.json()["included"][0]["type"]
# Out:
# 'Hidráulica'

# %%
res.json()["included"][0]["attributes"]["type"]
# Out:
# 'Renovable'

# %%
res.json()["included"][0]["attributes"]["values"][0]["datetime"]
# Out:
# '2011-01-01T00:00:00.000+01:00'

# %%
res.json()["included"][0]["attributes"]["values"]["value"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 res.json()["included"][0]["attributes"]["values"]["value"]
#
# TypeError: list indices must be integers or slices, not str
